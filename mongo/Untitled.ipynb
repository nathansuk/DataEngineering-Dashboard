# %%
import pandas as pd

# %%
data = pd.read_json("../scraping/test.json")

# %%
data = data[data["url"].isna()].reset_index(drop=True)
data = data.drop(columns=["url"])

# %%
data.head(30)
# Out:
#                                                 title  \
# 0                                         Xenonauts 2
# 1                        Tram Simulator Urban Transit
# 2                       EA Sports WRC Xbox Series X|S
# 3                   Train Sim World 4: Deluxe Edition
# 4                                       EA Sports WRC
# 5            Mortal Kombat 1 Premium Edition - Europe
# 6                      War Hospital Supporter Edition
# 7                                    Shadows of Doubt
# 8                                   Sonic Generations
# 9            Assassin's Creed: Director's Cut Edition
# 10              Dragon Ball FighterZ Ultimate Edition
# 11                         Bully: Scholarship Edition
# 12                   Les Sims 3: Destination Aventure
# 13                   Battlefield 5 Definitive Edition
# 14                    Nioh: Complete Edition - Europe
# 15                  Bloodstained: Ritual of the Night
# ...

# %%
data.iloc[1335]
# Out:
# title                                                       Les Sims 4 Saisons
# developers                                                               Maxis
# publisher                                                      Electronic Arts
# ig_review_average                                                           10
# ig_review_number                                                           242
# discounted                                                                  65
# date_published                                                    21 juin 2018
# final_price                                                              13.98
# tags                         [\nDLC\n, Simulation, Character Customization,...
# genres                                             ['Jeux solo', 'Simulation']
# original_selling_platform                                               EA App
# playable_platform                         [Mac, PC, Xbox One, Xbox Series X|S]
# ...
