# %%
import pandas as pd
import pymongo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[82], line 2
#       1 import pandas as pd
# ----> 2 import pymongo as pm
#
# ModuleNotFoundError: No module named 'pymongo'

# %%
data = pd.read_json("../scraping/instantGaming.json")

# %%
data = data[data["url"].isna()].reset_index(drop=True)
data = data.drop(columns=["url"])

# %%
data.head(30)
# Out:
#                                                 title  \
# 0                                  Yog-Sothoth's Yard
# 1   Naruto X Boruto Ultimate Ninja Storm Connectio...
# 2                                    Return from Core
# 3                                Dungeons of Sundaria
# 4                   Starfield Digital Premium Edition
# 5                            Mortal Kombat 1 - Europe
# 6            Farming Simulator 22 - Premium Expansion
# 7                                     Skull and Bones
# 8     Les Sims 4 À louer (Xbox One / Xbox Series X|S)
# 9                                             Celeste
# 10                                          Biomutant
# 11                                       Doom Eternal
# 12                    Devil May Cry 5 Deluxe + Vergil
# 13                                       Boomerang Fu
# 14                     Apex Legends: 11500 Apex Coins
# 15                                Zombie Army Trilogy
# 16  WRC 8 FIA World Rally Championship Deluxe Edition
# 17                        Two Point Hospital - Europe
# 18                                    Call of the Sea
# 19                                          Souldiers
# 20              Roblox 120 EUR - 10000 Robux - Europe
# 21                              Just Cause 2 - Europe
# 22                               Star Wars: Squadrons
# 23                             Mount & Blade: Warband
# 24                                             Anthem
# 25                                        Bloons TD 6
# 26                          Trine Ultimate Collection
# 27                                      Dirt Showdown
# 28  The Elder Scrolls IV: Oblivion GOTY Deluxe Edi...
# 29                                  Disney Pixar Cars
#
#                   developers                               publisher  \
# 0                  Bone Nail                               Bone Nail
# 1     CyberConnect2 Co. Ltd.              BANDAI NAMCO Entertainment
# 2              Tanxun Studio                                2P Games
# 3             Industry Games                          Industry Games
# 4      Bethesda Game Studios                      Bethesda Softworks
# 5        NetherRealm Studios  Warner Bros. Interactive Entertainment
# 6            Giants Software                         Giants Software
# 7                    Ubisoft                                 Ubisoft
# 8                      Maxis                         Electronic Arts
# 9   Extremely OK Games, Ltd.                   Matt Makes Games Inc.
# 10            Experiment 101                              THQ Nordic
# 11               id Software                      Bethesda Softworks
# 12          CAPCOM Co., Ltd.                        CAPCOM Co., Ltd.
# 13         Cranky Watermelon                       Cranky Watermelon
# 14     Respawn Entertainment                         Electronic Arts
# 15                 Rebellion                               Rebellion
# 16                      None                                    None
# 17         Two Point Studios                                    SEGA
# 18     Out of the Blue Games                                Raw Fury
# 19               Retro Forge                          Dear Villagers
# 20                      None                                    None
# 21         Avalanche Studios                             Square Enix
# 22                    MOTIVE                         Electronic Arts
# 23  TaleWorlds Entertainment                TaleWorlds Entertainment
# 24                   BioWare                         Electronic Arts
# 25                Ninja Kiwi                              Ninja Kiwi
# 26                Frozenbyte                             Modus Games
# 27                      None                                    None
# 28     Bethesda Game Studios                      Bethesda Softworks
# 29                    Beenox                                  Disney
#
#    ig_review_average ig_review_number discounted     date_published  \
# 0               None             None         54    20 octobre 2023
# 1                  8               27         34   16 novembre 2023
# 2               None             None         46   15 décembre 2023
# 3               None             None         36   12 décembre 2023
# 4                  7              271         40   1 septembre 2023
# 5                  9               37         57  19 septembre 2023
# 6               None             None         22   14 novembre 2023
# 7               None             None         20    16 février 2024
# 8                  7               24         20    7 décembre 2023
# 9                 10               37         77    25 janvier 2018
# 10                 7               98         85        25 mai 2021
# 11                10              170         80       20 mars 2020
# 12                10              106         70        8 mars 2019
# 13                10                8         93       13 août 2020
# 14              None             None         26     4 février 2019
# 15                 9               18         95        6 mars 2015
# 16                 9               22         94   8 septembre 2020
# 17                 9               59         77       30 août 2018
# 18                10               13         94    8 décembre 2020
# 19              None             None         95        2 juin 2022
# 20              None             None         13               None
# 21                 9               45         91       23 mars 2010
# 22                 7               29         90     2 octobre 2020
# 23                10               42         81       31 mars 2010
# 24              None              186         90    22 février 2019
# 25                10                9          6   18 décembre 2018
# 26                 9                4         84     8 octobre 2019
# 27                 9               34         93        24 mai 2012
# 28                10               71         72  11 septembre 2007
# 29                 8               29         87     6 juillet 2006
#
#    final_price                                               tags  \
# 0         4.99  ['Simulation', 'RPG', 'Dating Sim', 'Visual No...
# 1        56.19  ['Action', 'Adventure', 'Anime', '3D Fighter',...
# 2         8.89  ['Crafting', 'Survival', 'Automation', 'Base B...
# 3         9.53  ['Dungeon Crawler', 'Hack and Slash', 'RPG', '...
# 4        59.79  ['Space', 'Open World', 'RPG', 'Sci-fi', 'Expl...
# 5        29.99  ['Action', 'Fighting', 'Gore', 'Blood', 'Marti...
# 6        15.50                              ['DLC', 'Simulation']
# 7        47.99  ['Pirates', 'Naval', 'Open World', 'Naval Comb...
# 8        31.99  ['DLC', 'Life Sim', 'Character Customization',...
# 9         4.40  ['Precision Platformer', 'Difficult', 'Pixel G...
# 10        5.92  ['Open World', 'Action', 'RPG', 'Adventure', '...
# 11        7.97  ['Action', 'FPS', 'Gore', 'Fast-Paced', 'Demon...
# 12       12.19  ['Action', 'Hack and Slash', 'Character Action...
# 13        1.00  ['4 Player Local', 'Local Multiplayer', 'Famil...
# 14       74.42                                                 []
# 15        1.96  ['Zombies', 'Action', 'Co-op', 'World War II',...
# 16        2.34                                         ['Casual']
# 17        6.75  ['Simulation', 'Medical Sim', 'Management', 'B...
# 18        1.13  ['Adventure', 'Puzzle', 'Story Rich', 'First-P...
# 19        1.00  ['Metroidvania', 'Pixel Graphics', 'Action', '...
# 20      104.99                                                 []
# 21        1.37  ['Open World', 'Action', 'Sandbox', 'Third Per...
# 22        4.08  ['Flight', 'Space', 'VR', 'Sci-fi', 'Action', ...
# 23        3.84  ['Medieval', 'RPG', 'Open World', 'Strategy', ...
# 24        5.81                                                 []
# 25       12.99  ['Tower Defense', 'Strategy', 'Online Co-Op', ...
# 26       11.17                                                 []
# 27        1.00                                                 []
# 28        5.61  ['RPG', 'Open World', 'Fantasy', 'Moddable', '...
# 29        2.59  ['Racing', 'Illuminati', 'Memes', 'LGBTQ+', 'S...
#
#                                                genres  \
# 0        ['Jeux solo', 'Indies', 'RPG', 'Simulation']
# 1                 ['Jeux solo', 'Action', 'Aventure']
# 2   ['Jeux solo', 'Action', 'Aventure', 'Indies', ...
# 3   ['Jeux solo', 'Action', 'Aventure', 'Indies', ...
# 4                                ['Jeux solo', 'RPG']
# 5                             ['Jeux solo', 'Action']
# 6                         ['Jeux solo', 'Simulation']
# 7   ['Action', 'Aventure', 'Coopération', 'RPG', '...
# 8            ['Simulation', 'Stratégie', 'Jeux solo']
# 9       ['Jeux solo', 'Action', 'Aventure', 'Indies']
# 10                     ['Jeux solo', 'Action', 'RPG']
# 11                            ['Jeux solo', 'Action']
# 12                            ['Jeux solo', 'Action']
# 13                  ['Jeux solo', 'Action', 'Indies']
# 14  ['Action', 'Cartes Cadeau', 'FPS', 'Multijoueur']
# 15                            ['Jeux solo', 'Action']
# 16  ['Course', 'Simulation', 'Sport', 'Action', 'S...
# 17              ['Jeux solo', 'Indies', 'Simulation']
# 18                ['Jeux solo', 'Aventure', 'Indies']
# 19                ['Jeux solo', 'Action', 'Aventure']
# 20            ['Action', 'Aventure', 'Cartes Cadeau']
# 21                ['Jeux solo', 'Action', 'Aventure']
# 22              ['Jeux solo', 'Action', 'Simulation']
# 23                     ['Jeux solo', 'Action', 'RPG']
# 24            ['Action', 'FPS', 'Multijoueur', 'RPG']
# 25                         ['Jeux solo', 'Stratégie']
# 26      ['Action', 'Aventure', 'Indies', 'Jeux solo']
# 27                      ['Action', 'Course', 'Sport']
# 28                               ['Jeux solo', 'RPG']
# 29                ['Jeux solo', 'Aventure', 'Course']
#
#    original_selling_platform  \
# 0                      Steam
# 1                      Steam
# 2                      Steam
# 3                      Steam
# 4                      Steam
# 5                      Steam
# 6                      Steam
# 7            Ubisoft Connect
# 8            Xbox Series X|S
# 9                      Steam
# 10                     Steam
# 11                     Steam
# 12                     Steam
# 13                     Steam
# 14                    EA App
# 15                     Steam
# 16                     Steam
# 17                     Steam
# 18                     Steam
# 19                     Steam
# 20                      None
# 21                     Steam
# 22                     Steam
# 23                     Steam
# 24                    EA App
# 25                     Steam
# 26                     Steam
# 27                     Steam
# 28                     Steam
# 29                     Steam
#
#                                     playable_platform  \
# 0                                                [PC]
# 1                                                [PC]
# 2                                                [PC]
# 3                                                [PC]
# 4                               [PC, Xbox Series X|S]
# 5                               [PC, Xbox Series X|S]
# 6                                                [PC]
# 7                               [PC, Xbox Series X|S]
# 8                [Mac, PC, Xbox One, Xbox Series X|S]
# 9                            [Linux, Mac, PC, Switch]
# 10                    [PC, Xbox One, Xbox Series X|S]
# 11            [PC, Switch, Xbox One, Xbox Series X|S]
# 12                    [PC, Xbox One, Xbox Series X|S]
# 13                                               [PC]
# 14                    [PC, Xbox One, Xbox Series X|S]
# 15            [PC, Switch, Xbox One, Xbox Series X|S]
# 16               [PC, PS4, Xbox One, Xbox Series X|S]
# 17  [Linux, Mac, PC, PS4, Switch, Xbox One, Xbox S...
# 18                                               [PC]
# 19                                               [PC]
# 20                                               [PC]
# 21                                               [PC]
# 22  [PC - EA App, PC - Steam, Xbox One, Xbox Serie...
# 23                                               [PC]
# 24                    [PC, Xbox One, Xbox Series X|S]
# 25                                               [PC]
# 26                    [PC, Xbox One, Xbox Series X|S]
# 27                                               [PC]
# 28                                               [PC]
# 29                                               [PC]
#
#                                              editions
# 0                                                  {}
# 1   {'Edition standard': '40.99', 'Edition deluxe'...
# 2                                                  {}
# 3                                                  {}
# 4   {'Edition standard': '39.89', 'Digital Premium...
# 5   {'Edition standard': '29.99', 'Premium Edition...
# 6                                                  {}
# 7                                                  {}
# 8                                                  {}
# 9                                                  {}
# 10                                                 {}
# 11  {'Edition standard': '7.97', 'Edition deluxe':...
# 12    {'Edition standard': '7.75', 'Deluxe': '12.19'}
# 13                                                 {}
# 14  {'1000 Coins': '7.99', '2150 Coins': '15.49', ...
# 15                                                 {}
# 16  {'Edition standard': '2.21', 'Edition deluxe':...
# 17                                                 {}
# 18  {'Edition standard': '1.13', 'Edition deluxe':...
# 19                                                 {}
# 20  {'800 Robux': '11.49', '1700 Robux': 'None', '...
# 21                                                 {}
# 22                                                 {}
# 23                                                 {}
# 24                                                 {}
# 25                                                 {}
# 26                                                 {}
# 27                                                 {}
# 28  {'Game Of The Year Edition': '3.38', 'GOTY Del...
# 29                                                 {}
